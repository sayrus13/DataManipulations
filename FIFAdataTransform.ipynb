# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
play=pd.read_excel("/Users/artemysafronov/Downloads/players_20.xlsx")

# %%
play.head()
# Out:
#    sofifa_id         short_name                            long_name  age  \
# 0     158023           L. Messi      Lionel AndrГ©s Messi Cuccittini   32
# 1      20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34
# 2     190871          Neymar Jr        Neymar da Silva Santos Junior   27
# 3     200389           J. Oblak                            Jan Oblak   26
# 4     183277          E. Hazard                          Eden Hazard   28
#
#          dob  height_cm  weight_kg nationality                 club  overall  \
# 0 1987-06-24        170         72   Argentina         FC Barcelona       94
# 1 1985-02-05        187         83    Portugal             Juventus       93
# 2 1992-02-05        175         68      Brazil  Paris Saint-Germain       92
# 3 1993-01-07        188         87    Slovenia     AtlГ©tico Madrid       91
# 4 1991-01-07        175         74     Belgium          Real Madrid       91
#
# ...

# %%
print(play.columns.values)
# Out:
# ['sofifa_id' 'short_name' 'long_name' 'age' 'dob' 'height_cm' 'weight_kg'
#  'nationality' 'club' 'overall' 'potential' 'value_eur' 'wage_eur'
#  'player_positions' 'preferred_foot' 'international_reputation'
#  'weak_foot' 'skill_moves' 'work_rate' 'body_type' 'real_face'
#  'release_clause_eur' 'player_tags' 'team_position' 'team_jersey_number'
#  'loaned_from' 'joined' 'contract_valid_until' 'nation_position'
#  'nation_jersey_number' 'pace' 'shooting' 'passing' 'dribbling'
#  'defending' 'physic' 'gk_diving' 'gk_handling' 'gk_kicking' 'gk_reflexes'
#  'gk_speed' 'gk_positioning' 'player_traits' 'attacking_crossing'
#  'attacking_finishing' 'attacking_heading_accuracy'
#  'attacking_short_passing' 'attacking_volleys' 'skill_dribbling'
#  'skill_curve' 'skill_fk_accuracy' 'skill_long_passing'
#  'skill_ball_control' 'movement_acceleration' 'movement_sprint_speed'
#  'movement_agility' 'movement_reactions' 'movement_balance'
# ...

# %%
teams=play[(play["club"]=="FC Barcelona")|(play["club"]=="Borussia Dortmund")|(play["club"]=="Olympique de Marseille")|(play["club"]=="Manchester City")|(play["club"]=="Inter")]

# %%
teams
# Out:
#        sofifa_id     short_name                           long_name  age  \
# 0         158023       L. Messi     Lionel AndrГ©s Messi Cuccittini   32
# 5         192985   K. De Bruyne                     Kevin De Bruyne   28
# 6         192448  M. ter Stegen              Marc-AndrГ© ter Stegen   27
# 17        153079     S. AgГјero  Sergio Leonel AgГјero del Castillo   31
# 19        176580     L. SuГЎrez          Luis Alberto SuГЎrez DГ­az   32
# ...          ...            ...                                 ...  ...
# 16421     250931   P. Osterhage                   Patrick Osterhage   19
# 16743     240473      T. Wilson                       Tyreke Wilson   19
# 17139     251340         A. Dia                         Ahmadou Dia   19
# 17167     224947    D. Grimshaw                     Daniel Grimshaw   21
# 17961     243200  S. Mulattieri                  Samuele Mulattieri   18
#
#              dob  height_cm  weight_kg          nationality  \
# ...

# %%
gk=teams[teams["team_position"]=="GK"]

# %%
gk
# Out:
#      sofifa_id      short_name                  long_name  age        dob  \
# 6       192448   M. ter Stegen     Marc-AndrГ© ter Stegen   27 1992-04-30
# 25      210257         Ederson  Ederson Santana de Moraes   25 1993-08-17
# 30      162835  S. HandanoviДЌ          Samir HandanoviДЌ   34 1984-07-14
# 88      189117       R. BГјrki               Roman BГјrki   28 1990-11-14
# 500     163705     S. Mandanda             Steve Mandanda   34 1985-03-28
#
#      height_cm  weight_kg  nationality                    club  overall  ...  \
# 6          187         85      Germany            FC Barcelona       90  ...
# 25         188         86       Brazil         Manchester City       88  ...
# 30         193         92     Slovenia                   Inter       88  ...
# 88         187         85  Switzerland       Borussia Dortmund       85  ...
# 500        185         80       France  Olympique de Marseille       80  ...
#
#      lwb  ldm  cdm  rdm  rwb   lb  lcb   cb  rcb   rb
# ...

# %%
gk_attr=gk[["club","short_name","age",'height_cm',"overall","wage_eur","value_eur","potential","goalkeeping_diving","goalkeeping_handling","goalkeeping_reflexes"]]

# %%
gk_fin = gk_attr.drop_duplicates('club')

# %%
gk_fin
# Out:
#                        club      short_name  age  height_cm  overall  \
# 6              FC Barcelona   M. ter Stegen   27        187       90
# 25          Manchester City         Ederson   25        188       88
# 30                    Inter  S. HandanoviДЌ   34        193       88
# 88        Borussia Dortmund       R. BГјrki   28        187       85
# 500  Olympique de Marseille     S. Mandanda   34        185       80
#
#      wage_eur  value_eur  potential  goalkeeping_diving  goalkeeping_handling  \
# 6      250000   67500000         93                  88                    85
# 25     185000   54500000         91                  86                    82
# 30     110000   26000000         88                  88                    85
# 88      92000   32000000         86                  86                    80
# 500     32000    6500000         80                  80                    79
#
#      goalkeeping_reflexes
# 6                      90
# 25                     88
# ...

# %%
gk_fin.to_excel("/Users/artemysafronov/Downloads/GK.xlsx", sheet_name="GK")

# %%
cb=teams[teams["team_position"].isin(["CB","LCB","RCB"])]

# %%
cb
# Out:
#       sofifa_id    short_name                   long_name  age        dob  \
# 29       152729        PiquГ©     Gerard PiquГ© BernabГ©u   32 1987-02-02
# 35       182493     D. GodГ­n                Diego GodГ­n   33 1986-02-16
# 40       212218    A. Laporte            Aymeric  Laporte   25 1994-05-27
# 49       178603    M. Hummels               Mats  Hummels   30 1988-12-16
# 57       232363  M. Е kriniar             Milan Е kriniar   24 1995-02-11
# 84       220440    C. Lenglet            ClГ©ment Lenglet   24 1995-06-17
# 126      198176    S. de Vrij              Stefan de Vrij   27 1992-02-05
# 170      229237     M. Akanji       Manuel Obafemi Akanji   23 1995-07-19
# 172      203574     J. Stones                 John Stones   25 1994-05-28
# 961      202935       ГЃlvaro  ГЃlvaro GonzГЎlez SoberГіn   29 1990-01-08
# 1623     236987     B. Kamara             Boubacar Kamara   19 1999-11-23
#
#       height_cm  weight_kg  nationality                    club  overall  ...  \
# ...

# %%
cb_attr=cb[["club","short_name","age",'height_cm',"overall","wage_eur","value_eur","potential",'defending','physic',  'defending_marking']]

# %%
cb_fin = cb_attr.groupby('club').nth([0, 1])

# %%
cb_fin
# Out:
#                           short_name  age  height_cm  overall  wage_eur  \
# club
# Borussia Dortmund         M. Hummels   30        191       87    130000
# Borussia Dortmund          M. Akanji   23        187       83     77000
# FC Barcelona                  PiquГ©   32        194       88    285000
# FC Barcelona              C. Lenglet   24        186       85    175000
# Inter                      D. GodГ­n   33        187       88    135000
# Inter                   M. Е kriniar   24        187       86     89000
# Manchester City           A. Laporte   25        189       87    195000
# Manchester City            J. Stones   25        188       83    140000
# Olympique de Marseille       ГЃlvaro   29        183       78     36000
# Olympique de Marseille     B. Kamara   19        178       75     15000
#
#                         value_eur  potential  defending  physic  \
# club
# Borussia Dortmund        41000000         87       89.0    76.0
# ...

# %%
cb_fin.to_excel("/Users/artemysafronov/Downloads/CB.xlsx", sheet_name="CB")

# %%
lb=teams[teams["player_positions"].isin(["LB","LB,RB","LWB,LM,LB"])]

# %%
lb_attr=lb[["club","short_name","age",'height_cm',"overall","wage_eur","value_eur","potential",'defending','pace', 'attacking_crossing']]

# %%
lb_fin = lb_attr.drop_duplicates('club')

# %%
lb_fin
# Out:
#                         club    short_name  age  height_cm  overall  wage_eur  \
# 51              FC Barcelona    Jordi Alba   30        170       87    240000
# 429          Manchester City      B. Mendy   24        185       80     96000
# 698                    Inter    K. Asamoah   30        173       79     60000
# 1516       Borussia Dortmund  M. Schmelzer   31        181       76     53000
# 2263  Olympique de Marseille      J. Amavi   25        176       74     25000
#
#       value_eur  potential  defending  pace  attacking_crossing
# 51     40000000         87       79.0  90.0                  87
# 429    17500000         85       77.0  81.0                  87
# 698    10000000         79       79.0  74.0                  78
# 1516    5500000         76       76.0  74.0                  72
# 2263    6500000         78       69.0  77.0                  75

# %%
lb_fin.to_excel("/Users/artemysafronov/Downloads/LB.xlsx", sheet_name="GK")

# %%
rb=teams[teams["player_positions"].isin(["RB","RB, LB","RB, RM"])]

# %%
rb_attr=rb[["club","short_name","age",'height_cm',"overall","wage_eur","value_eur","potential",'defending','pace', 'attacking_crossing']]

# %%
rb_fin = rb_attr.drop_duplicates('club')

# %%
rb_fin
# Out:
#                         club      short_name  age  height_cm  overall  \
# 112          Manchester City   JoГЈo Cancelo   25        182       84
# 249             FC Barcelona  NГ©lson Semedo   25        177       82
# 382        Borussia Dortmund     L. Piszczek   34        184       81
# 970   Olympique de Marseille        H. Sakai   29        183       78
# 1757                   Inter       V. Lazaro   23        180       75
#
#       wage_eur  value_eur  potential  defending  pace  attacking_crossing
# 112     150000   36500000         89       78.0  90.0                  86
# 249     150000   26000000         87       77.0  92.0                  76
# 382      76000    6000000         81       82.0  77.0                  82
# 970      36000    8500000         78       76.0  78.0                  74
# 1757     39000    7500000         79       69.0  84.0                  80

# %%
rb_fin.to_excel("/Users/artemysafronov/Downloads/rb.xlsx", sheet_name="GK")

# %%
cdm=teams[teams["player_positions"].isin(["CDM","CDM, CM","CDM, CB"])]

# %%
cdm_attr=cdm[["club","short_name","age",'height_cm',"overall","wage_eur","value_eur","potential",'defending','passing', 'physic']]

# %%
cdm_attr
# Out:
#                          club       short_name  age  height_cm  overall  \
# 21               FC Barcelona  Sergio Busquets   30        189       89
# 44            Manchester City      Fernandinho   34        179       87
# 79            Manchester City            Rodri   23        191       85
# 102         Borussia Dortmund        A. Witsel   30        186       85
# 271         Borussia Dortmund       T. Delaney   27        182       82
# 361                     Inter     M. BrozoviД‡   26        181       81
# 394    Olympique de Marseille     Luiz Gustavo   31        187       81
# 446         Borussia Dortmund         J. Weigl   23        186       80
# 484                     Inter        M. Vecino   27        187       80
# 821                     Inter   R. Gagliardini   25        190       78
# 4781             FC Barcelona          L. Reis   19        178       70
# 5396   Olympique de Marseille        G. Sertic   29        183       70
# ...

# %%
cdm_attr_def=cdm_attr.sort_values("defending",ascending=False)

# %%
cdm_fin=cdm_attr_def.drop_duplicates('club')

# %%
cdm_fin
# Out:
#                        club       short_name  age  height_cm  overall  \
# 21             FC Barcelona  Sergio Busquets   30        189       89
# 44          Manchester City      Fernandinho   34        179       87
# 102       Borussia Dortmund        A. Witsel   30        186       85
# 394  Olympique de Marseille     Luiz Gustavo   31        187       81
# 821                   Inter   R. Gagliardini   25        190       78
#
#      wage_eur  value_eur  potential  defending  passing  physic
# 21     300000   55000000         89       85.0     80.0    80.0
# 44     200000   19500000         87       84.0     79.0    79.0
# 102    110000   31500000         85       83.0     80.0    81.0
# 394     42000   13500000         81       80.0     69.0    82.0
# 821     51000   12000000         81       77.0     71.0    73.0

# %%
cdm_fin.to_excel("/Users/artemysafronov/Downloads/cdm.xlsx", sheet_name="GK")

# %%
cm=teams[teams["player_positions"].isin(["CM","CM, CDM","CM, CAM"])]

# %%
cm_attr=cm[["club","short_name","age",'height_cm',"overall","wage_eur","value_eur","potential","dribbling",'passing', 'mentality_vision' ]]

# %%
cm_attr_pass=cm_attr.sort_values("passing",ascending=False)

# %%
cm_fin=cm_attr_pass.drop_duplicates('club')

# %%
cm_fin
# Out:
#                         club     short_name  age  height_cm  overall  \
# 64              FC Barcelona    I. RakitiД‡   31        184       86
# 146          Manchester City  I. GГјndoДџan   28        180       84
# 533   Olympique de Marseille   K. Strootman   29        186       80
# 1059                   Inter       S. Sensi   23        168       77
# 773        Borussia Dortmund      M. Dahoud   23        178       78
#
#       wage_eur  value_eur  potential  dribbling  passing  mentality_vision
# 64      245000   38000000         86       81.0     86.0                85
# 146     180000   31000000         84       84.0     84.0                86
# 533      45000   14000000         80       73.0     80.0                79
# 1059     48000   11500000         82       76.0     79.0                80
# 773      58000   14000000         84       84.0     75.0                80

# %%
cm_fin.to_excel("/Users/artemysafronov/Downloads/cm.xlsx", sheet_name="GK")

# %%
cam=teams[teams["player_positions"].isin(["CM","CM, CAM","CM, CDM","CAM, CM","CAM, LM, ST"])]

# %%
cam_attr=cam[["club","short_name","age",'height_cm',"overall","wage_eur","value_eur","potential","dribbling",'passing', 'shooting']]

# %%
cam_attr_drib=cam_attr.sort_values("potential",ascending=False)

# %%
cam_fin=cam_attr_drib.drop_duplicates('club')

# %%
cam_fin
# Out:
#                        club    short_name  age  height_cm  overall  wage_eur  \
# 5           Manchester City  K. De Bruyne   28        181       91    370000
# 75             FC Barcelona    F. de Jong   22        180       85    195000
# 37        Borussia Dortmund       M. Reus   30        180       88    170000
# 412                   Inter    N. Barella   22        175       80     60000
# 619  Olympique de Marseille     M. Sanson   24        180       79     36000
#
#      value_eur  potential  dribbling  passing  shooting
# 5     90000000         91       86.0     92.0      86.0
# 75    52000000         91       87.0     84.0      64.0
# 37    56000000         88       87.0     84.0      88.0
# 412   21500000         88       80.0     78.0      66.0
# 619   16000000         83       77.0     78.0      73.0

# %%
cam_fin.to_excel("/Users/artemysafronov/Downloads/cam.xlsx", sheet_name="GK")

# %%
rw=teams[teams["player_positions"].isin(["RM","RW","RM, LM","RM, RW","RW, RM","RW, LW","RW, CF, ST","RW, CAM, CM"])]

# %%
rw_attr=rw[["club","short_name","age",'height_cm',"overall","wage_eur","value_eur","potential","dribbling",'pace', 'shooting']]

# %%
rw_attr_drib=rw_attr.sort_values("dribbling",ascending=False)

# %%
rw_fin=rw_attr_drib.drop_duplicates('club')

# %%
rw_fin
# Out:
#                        club      short_name  age  height_cm  overall  \
# 0              FC Barcelona        L. Messi   32        170       94
# 41          Manchester City  Bernardo Silva   24        173       87
# 108       Borussia Dortmund       J. Sancho   19        180       84
# 198  Olympique de Marseille      F. Thauvin   26        179       83
# 678                   Inter     A. Candreva   32        180       79
#
#      wage_eur  value_eur  potential  dribbling  pace  shooting
# 0      565000   95500000         94       96.0  87.0      92.0
# 41     210000   64000000         90       92.0  81.0      76.0
# 108     61000   44500000         92       90.0  88.0      72.0
# 198     60000   30500000         84       83.0  83.0      80.0
# 678     65000   10000000         79       80.0  74.0      78.0

# %%
rw_fin.to_excel("/Users/artemysafronov/Downloads/rw.xlsx", sheet_name="GK")

# %%
lw=teams[teams["player_positions"].isin(["LM","LW","LM, RM","RM, LM, CF","LM, LW","CAM, LW","LW, LM","LW, RW","RW, LW","ST","CF, ST, LW"])]

# %%
lw_attr=lw[["club","short_name","age",'height_cm',"overall","wage_eur","value_eur","potential","dribbling",'pace', 'shooting']]

# %%
lw_attr_pace=lw_attr.sort_values("dribbling",ascending=False)

# %%
lw_fin=lw_attr_pace.drop_duplicates('club')

# %%
lw_fin
# Out:
#                        club    short_name  age  height_cm  overall  wage_eur  \
# 22             FC Barcelona  A. Griezmann   28        176       89    370000
# 26          Manchester City   R. Sterling   24        170       88    255000
# 281       Borussia Dortmund     T. Hazard   26        175       82     90000
# 329                   Inter  L. MartГ­nez   21        174       81     61000
# 384  Olympique de Marseille      D. Payet   32        175       81     46000
#
#      value_eur  potential  dribbling  pace  shooting
# 22    69000000         89       89.0  81.0      86.0
# 26    73000000         90       89.0  93.0      79.0
# 281   26000000         83       86.0  82.0      77.0
# 329   27000000         89       82.0  81.0      77.0
# 384   14000000         81       81.0  71.0      77.0

# %%
lw_fin.to_excel("/Users/artemysafronov/Downloads/lw.xlsx", sheet_name="GK")

# %%
st=teams[teams["player_positions"].isin(["ST","CF","ST, CF","CF, ST"])]

# %%
st_attr=st[["club","short_name","age",'height_cm',"overall","wage_eur","value_eur","potential",'weak_foot','pace', 'shooting']]

# %%
st_fin=st_attr.drop_duplicates('club')

# %%
st_fin
# Out:
#                        club     short_name  age  height_cm  overall  wage_eur  \
# 17          Manchester City     S. AgГјero   31        173       89    300000
# 19             FC Barcelona     L. SuГЎrez   32        182       89    355000
# 89                    Inter      R. Lukaku   26        190       85    115000
# 186       Borussia Dortmund  Paco AlcГЎcer   25        175       83    105000
# 737  Olympique de Marseille   D. Benedetto   29        177       79     46000
#
#      value_eur  potential  weak_foot  pace  shooting
# 17    60000000         89          4  80.0      90.0
# 19    53000000         89          4  73.0      89.0
# 89    46000000         86          4  75.0      82.0
# 186   32000000         85          4  79.0      84.0
# 737   12500000         79          5  80.0      80.0

# %%
st_fin.to_excel("/Users/artemysafronov/Downloads/st.xlsx", sheet_name="GK")
